# %% [markdown]
# # Análise Exploratória — Detecção de Fraude Bancária\nNotebook introdutório usando Pandas.

# %%
import pandas as pd\nfrom src.gerar_dados import gerar_transacoes\n\ndf = gerar_transacoes()\ndf.head()

# %%
df.info()

# %%
df['fraude'].value_counts(normalize=True).mul(100).round(2)

# %%
df.groupby('fraude')['valor'].describe()

# %%
df.groupby('fraude')[['valor','distancia_casa_km','transacoes_1h']].mean()
